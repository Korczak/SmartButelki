# %%
import cv2
import os
import shutil
import matplotlib.pyplot as plt

# %%
img_width, img_height = 312, 416

# %%
def resize_dataset():
    resized_images = 0

    directory = "../../dataset/butelka/"
    processed_path = os.path.join("../../dataset/butelka/train_resized/")
    if os.path.exists(processed_path):
        shutil.rmtree(processed_path)
    os.mkdir(processed_path)
    for root, subdirs, files in os.walk(directory):
        for image in files:
            img = cv2.imread(root+"/"+image, cv2.IMREAD_UNCHANGED)
            if(img.shape[0] < img.shape[1]):
                img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
            img = cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_AREA)
            cv2.imwrite(processed_path + '/' + image, img);
            resized_images = resized_images + 1
            if(resized_images % 20 == 0):
                print(resized_images)
                #input('Kontynuować?')
                
resize_dataset()
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100

# %%
img = cv2.imread("../lokalny_dataset/train_images/full_bottle/IMG_1070.JPG", cv2.IMREAD_UNCHANGED)
print(img.shape)

plt.imshow(img)
plt.show()
# Out:
# (3024, 4032, 3)

# %%
4032/3024
# Out:
# 1.3333333333333333

# %%
416/1.333
# Out:
# 312.07801950487624
