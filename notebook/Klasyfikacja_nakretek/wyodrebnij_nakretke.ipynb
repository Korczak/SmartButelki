# %%
import xml.etree.ElementTree as ET
import os
from glob import glob
import cv2

# %%
XML_PATH = '../../dataset/train_annotations_voc/'
IMAGE_PATH = '../../dataset/train_images/'

CLASSES_PATH = '../../class_names/butelka_classes.txt'
DEST_PATH = '../../dataset/bottle_top_train/'

'''loads the classes'''
def get_classes(classes_path):
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names


classes = get_classes(CLASSES_PATH)
assert len(classes) > 0, 'no class names detected!'
print(f'num classes: {len(classes)}')
# Out:
# num classes: 1

# %%
def convert_xmls(directory, num_files=20):
    num_files_converted = 0
    
    try:
        os.mkdir(os.path.join(DEST_PATH, directory))
    except OSError as error:
        print(error)    
    
    for path in glob(os.path.join(XML_PATH, directory, '*.xml')):
        if(num_files_converted >= num_files):
            break
        in_file = open(path)

        # Parse .xml file
        tree = ET.parse(in_file)
        root = tree.getroot()
        # Write object information to .txt file
        file_name = root.find('filename').text
        print(file_name)
        try:
            obj = next(root.iter('object'))
            cls = obj.find('name').text 
            cls_id = classes.index(cls)
            xmlbox = obj.find('bndbox')
            b = (int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text))
            img = cv2.imread(os.path.join(IMAGE_PATH, directory, file_name), cv2.IMREAD_UNCHANGED)
            img = img[b[1]:b[3], b[0]:b[2]]
            cv2.imwrite(os.path.join(DEST_PATH, directory, file_name), img)
        
            num_files_converted = num_files_converted + 1
        except Exception as error:
            print(error)

# %%
dirs = ['brak_banderoli', 'brak_nakretki', 'niedokrecona_nakretka', 'prawidlowa', 'przekrzywiona_nakretka', 'uszkodzona_banderola']

# %%
for dir in dirs:
    convert_xmls(dir, 20)
# Out:
# [Errno 17] File exists: '../dataset/bottle_top_train/brak_banderoli'
# IMG_5043.JPG
# IMG_4930.JPG
# IMG_4913.JPG
# IMG_5319.JPG
# IMG_5089.JPG
# IMG_5039.JPG
# IMG_5363.JPG
# IMG_4956.JPG
# IMG_4972.JPG
# IMG_4984.JPG
# IMG_5335.JPG
# IMG_4925.JPG
# IMG_5280.JPG
# IMG_5129.JPG
# IMG_5123.JPG
# IMG_5302.JPG
# IMG_5303.JPG
# IMG_5364.JPG
# IMG_5373.JPG
# IMG_4974.JPG
# [Errno 17] File exists: '../dataset/bottle_top_train/brak_nakretki'
# IMG_6469.JPG
# IMG_6558.JPG
# 'NoneType' object is not subscriptable
# IMG_6595.JPG
# IMG_6117.JPG
# IMG_6655.JPG
# IMG_6077.JPG
# IMG_6716.JPG
# IMG_6170.JPG
# IMG_6230.JPG
# 'NoneType' object is not subscriptable
# IMG_6333.JPG
# IMG_6048.JPG
# IMG_6299.JPG
# IMG_6763.JPG
# IMG_6625.JPG
# 'NoneType' object is not subscriptable
# IMG_6247.JPG
# 'NoneType' object is not subscriptable
# IMG_6715.JPG
# IMG_6390.JPG
# IMG_6141.JPG
# 'NoneType' object is not subscriptable
# IMG_6652.JPG
# IMG_6867.JPG
# 'NoneType' object is not subscriptable
# IMG_6503.JPG
# IMG_6789.JPG
# IMG_6755.JPG
# 'NoneType' object is not subscriptable
# IMG_6349.JPG
# IMG_6968.JPG
# 'NoneType' object is not subscriptable
# IMG_6431.JPG
# IMG_6880.JPG
# IMG_6646.JPG
# [Errno 17] File exists: '../dataset/bottle_top_train/niedokrecona_nakretka'
# IMG_0030.JPG
# IMG_9043.JPG
# IMG_9353.JPG
# IMG_9425.JPG
# IMG_9299.JPG
# IMG_9101.JPG
# IMG_9174.JPG
# IMG_9347.JPG
# IMG_9138.JPG
# IMG_9267.JPG
# IMG_9103.JPG
# IMG_9458.JPG
# IMG_9211.JPG
# IMG_9077.JPG
# IMG_9208.JPG
# IMG_9076.JPG
# IMG_9326.JPG
# IMG_9086.JPG
# IMG_9070.JPG
# IMG_0023.JPG
# IMG_3840.JPG
# IMG_3700.JPG
# IMG_3493.JPG
# IMG_3439.JPG
# IMG_3342.JPG
# IMG_3526.JPG
# IMG_3507.JPG
# IMG_3447.JPG
# IMG_3744.JPG
# IMG_3246.JPG
# IMG_3518.JPG
# IMG_3228.JPG
# IMG_3073.JPG
# IMG_3887.JPG
# IMG_3296.JPG
# IMG_3552.JPG
# IMG_3528.JPG
# IMG_3745.JPG
# IMG_3633.JPG
# IMG_3292.JPG
# IMG_8483.JPG
# IMG_8303.JPG
# IMG_8037.JPG
# IMG_8439.JPG
# IMG_8467.JPG
# IMG_8132.JPG
# IMG_8511.JPG
# IMG_8137.JPG
# IMG_8308.JPG
# IMG_8442.JPG
# IMG_8404.JPG
# IMG_8481.JPG
# IMG_8403.JPG
# IMG_8506.JPG
# IMG_8469.JPG
# IMG_8147.JPG
# IMG_8106.JPG
# IMG_8046.JPG
# IMG_8407.JPG
# IMG_8429.JPG
# IMG_0354.JPG
# IMG_0263.JPG
# IMG_0125.JPG
# IMG_0356.JPG
# IMG_0131.JPG
# IMG_0402.JPG
# IMG_0227.JPG
# IMG_0301.JPG
# IMG_0225.JPG
# IMG_0190.JPG
# IMG_0098.JPG
# IMG_0208.JPG
# IMG_0448.JPG
# IMG_0251.JPG
# IMG_0364.JPG
# IMG_0122.JPG
# IMG_0081.JPG
# IMG_0292.JPG
# IMG_0438.JPG
# IMG_0170.JPG
